# %% [markdown]
# <a href="https://colab.research.google.com/github/garyrmeadeTettey/Smallscale-Projects/blob/main/EnergyData1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib notebook
import numpy as np
import pandas as pd

# %%
import seaborn as sns

# %%
data = pd.read_csv('owid-energy-data.csv')

# %%
from google.colab import files
  
  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-125f12b0-94bd-4399-80c2-ac4a8fda481f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-125f12b0-94bd-4399-80c2-ac4a8fda481f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving owid-energy-data.csv to owid-energy-data.csv

# %%
print(data.head())
# Out:
#   iso_code      country  ...  wind_elec_per_capita  wind_energy_per_capita
# 0      AFG  Afghanistan  ...                   NaN                     NaN
# 1      AFG  Afghanistan  ...                   NaN                     NaN
# 2      AFG  Afghanistan  ...                   NaN                     NaN
# 3      AFG  Afghanistan  ...                   NaN                     NaN
# 4      AFG  Afghanistan  ...                   NaN                     NaN
#
# [5 rows x 122 columns]

# %%
print(data.shape)
print(data.info)
# Out:
# (17432, 122)
# <bound method DataFrame.info of       iso_code      country  ...  wind_elec_per_capita  wind_energy_per_capita
# 0          AFG  Afghanistan  ...                   NaN                     NaN
# 1          AFG  Afghanistan  ...                   NaN                     NaN
# 2          AFG  Afghanistan  ...                   NaN                     NaN
# 3          AFG  Afghanistan  ...                   NaN                     NaN
# 4          AFG  Afghanistan  ...                   NaN                     NaN
# ...        ...          ...  ...                   ...                     ...
# 17427      ZWE     Zimbabwe  ...                   0.0                     NaN
# 17428      ZWE     Zimbabwe  ...                   0.0                     NaN
# 17429      ZWE     Zimbabwe  ...                   0.0                     NaN
# 17430      ZWE     Zimbabwe  ...                   0.0                     NaN
# ...

# %%
data.head(10).style.background_gradient()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/style.py:1126: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/style.py:1127: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
# ...

# %%
data.tail(10).style.background_gradient()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/style.py:1126: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/style.py:1127: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
# ...

# %%
plt.scatter(x=data['year'], y=data['electricity_generation'])
plt.title("Scatter plot of electricity generation")
# Out:
# Text(0.5, 1.0, 'Scatter plot of electricity generation')

# %%
corr = data.corr()
print(corr)
# Out:
#                             year  ...  wind_energy_per_capita
# year                    1.000000  ...                0.334819
# coal_prod_change_pct   -0.004797  ...               -0.038436
# coal_prod_change_twh    0.040297  ...               -0.084297
# gas_prod_change_pct     0.017294  ...               -0.007974
# gas_prod_change_twh     0.131712  ...                0.051505
# ...                          ...  ...                     ...
# wind_share_energy       0.335624  ...                0.948205
# wind_cons_change_twh    0.159462  ...                0.139815
# wind_consumption        0.159244  ...                0.175252
# wind_elec_per_capita    0.236679  ...                0.999265
# wind_energy_per_capita  0.334819  ...                1.000000
#
# [120 rows x 120 columns]
